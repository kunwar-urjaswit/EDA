# %% [markdown]
# ## 1. Importing Libraries and reading the data

# %%
# Filtering out the warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# setting options to view large data

pd.set_option('display.max_rows', 400)
pd.set_option('display.max_columns', 400)

# %%
# Read the current application csv file

apld = pd.read_csv("application_data.csv")

# %% [markdown]
# ## 2. Performing Descriptive Analysis on the Raw Data

# %%
# Check the number of rows and columns in the dataframe

apld.shape
# Out:
# (307511, 122)

# %%
# Check the column-wise info of the dataframe

apld.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 122 columns):
#  #    Column                        Non-Null Count   Dtype
# ---   ------                        --------------   -----
#  0    SK_ID_CURR                    307511 non-null  int64
#  1    TARGET                        307511 non-null  int64
#  2    NAME_CONTRACT_TYPE            307511 non-null  object
#  3    CODE_GENDER                   307511 non-null  object
#  4    FLAG_OWN_CAR                  307511 non-null  object
#  5    FLAG_OWN_REALTY               307511 non-null  object
#  6    CNT_CHILDREN                  307511 non-null  int64
#  7    AMT_INCOME_TOTAL              307511 non-null  float64
#  8    AMT_CREDIT                    307511 non-null  float64
#  9    AMT_ANNUITY                   307499 non-null  float64
#  10   AMT_GOODS_PRICE               307233 non-null  float64
#  11   NAME_TYPE_SUITE               306219 non-null  object
# ...

# %%
apld.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# ...

# %%
# check unique values of columns

for i in apld.columns:
    print(i,apld[i].nunique())
# Out:
# SK_ID_CURR 307511
# TARGET 2
# NAME_CONTRACT_TYPE 2
# CODE_GENDER 3
# FLAG_OWN_CAR 2
# FLAG_OWN_REALTY 2
# CNT_CHILDREN 15
# AMT_INCOME_TOTAL 2548
# AMT_CREDIT 5603
# AMT_ANNUITY 13672
# AMT_GOODS_PRICE 1002
# NAME_TYPE_SUITE 7
# NAME_INCOME_TYPE 8
# NAME_EDUCATION_TYPE 5
# NAME_FAMILY_STATUS 6
# NAME_HOUSING_TYPE 6
# REGION_POPULATION_RELATIVE 81
# DAYS_BIRTH 17460
# DAYS_EMPLOYED 12574
# DAYS_REGISTRATION 15688
# DAYS_ID_PUBLISH 6168
# OWN_CAR_AGE 62
# FLAG_MOBIL 2
# FLAG_EMP_PHONE 2
# FLAG_WORK_PHONE 2
# FLAG_CONT_MOBILE 2
# FLAG_PHONE 2
# FLAG_EMAIL 2
# OCCUPATION_TYPE 18
# CNT_FAM_MEMBERS 17
# REGION_RATING_CLIENT 3
# REGION_RATING_CLIENT_W_CITY 3
# WEEKDAY_APPR_PROCESS_START 7
# HOUR_APPR_PROCESS_START 24
# REG_REGION_NOT_LIVE_REGION 2
# REG_REGION_NOT_WORK_REGION 2
# LIVE_REGION_NOT_WORK_REGION 2
# REG_CITY_NOT_LIVE_CITY 2
# REG_CITY_NOT_WORK_CITY 2
# LIVE_CITY_NOT_WORK_CITY 2
# ORGANIZATION_TYPE 58
# EXT_SOURCE_1 114584
# EXT_SOURCE_2 119831
# EXT_SOURCE_3 814
# ...

# %%
# Sorting the columns to check the null %

round((apld.isnull().sum()/apld.index.size)*100,2).sort_values(ascending=False)
# Out:
# COMMONAREA_MEDI                 69.87
# COMMONAREA_AVG                  69.87
# COMMONAREA_MODE                 69.87
# NONLIVINGAPARTMENTS_MODE        69.43
# NONLIVINGAPARTMENTS_AVG         69.43
# NONLIVINGAPARTMENTS_MEDI        69.43
# FONDKAPREMONT_MODE              68.39
# LIVINGAPARTMENTS_MODE           68.35
# LIVINGAPARTMENTS_AVG            68.35
# LIVINGAPARTMENTS_MEDI           68.35
# FLOORSMIN_AVG                   67.85
# FLOORSMIN_MODE                  67.85
# FLOORSMIN_MEDI                  67.85
# YEARS_BUILD_MEDI                66.50
# YEARS_BUILD_MODE                66.50
# YEARS_BUILD_AVG                 66.50
# OWN_CAR_AGE                     65.99
# LANDAREA_MEDI                   59.38
# LANDAREA_MODE                   59.38
# LANDAREA_AVG                    59.38
# BASEMENTAREA_MEDI               58.52
# BASEMENTAREA_AVG                58.52
# BASEMENTAREA_MODE               58.52
# EXT_SOURCE_1                    56.38
# NONLIVINGAREA_MODE              55.18
# ...

# %% [markdown]
# ## 3. Filling NA values and dropping columns

# %%
# Accessing columns where there are more than 45% null values
droplist_col = []
droplist_col = list(apld.columns[((apld.isnull().sum()/apld.index.size)*100) >= 45])

# %%
# Appending columns from current application data to drop list, which we felt are not relevant.

droplist_col.extend(['AMT_REQ_CREDIT_BUREAU_HOUR','AMT_REQ_CREDIT_BUREAU_DAY',
                   'AMT_REQ_CREDIT_BUREAU_WEEK','AMT_REQ_CREDIT_BUREAU_MON','AMT_REQ_CREDIT_BUREAU_QRT',
                   'AMT_REQ_CREDIT_BUREAU_YEAR'])

# %%
# Checking the drop list variable

droplist_col
# Out:
# ['OWN_CAR_AGE',
#  'EXT_SOURCE_1',
#  'APARTMENTS_AVG',
#  'BASEMENTAREA_AVG',
#  'YEARS_BEGINEXPLUATATION_AVG',
#  'YEARS_BUILD_AVG',
#  'COMMONAREA_AVG',
#  'ELEVATORS_AVG',
#  'ENTRANCES_AVG',
#  'FLOORSMAX_AVG',
#  'FLOORSMIN_AVG',
#  'LANDAREA_AVG',
#  'LIVINGAPARTMENTS_AVG',
#  'LIVINGAREA_AVG',
#  'NONLIVINGAPARTMENTS_AVG',
#  'NONLIVINGAREA_AVG',
#  'APARTMENTS_MODE',
#  'BASEMENTAREA_MODE',
#  'YEARS_BEGINEXPLUATATION_MODE',
#  'YEARS_BUILD_MODE',
#  'COMMONAREA_MODE',
#  'ELEVATORS_MODE',
#  'ENTRANCES_MODE',
#  'FLOORSMAX_MODE',
#  'FLOORSMIN_MODE',
#  'LANDAREA_MODE',
#  'LIVINGAPARTMENTS_MODE',
#  'LIVINGAREA_MODE',
#  'NONLIVINGAPARTMENTS_MODE',
#  'NONLIVINGAREA_MODE',
#  'APARTMENTS_MEDI',
#  'BASEMENTAREA_MEDI',
#  'YEARS_BEGINEXPLUATATION_MEDI',
#  'YEARS_BUILD_MEDI',
#  'COMMONAREA_MEDI',
#  'ELEVATORS_MEDI',
#  'ENTRANCES_MEDI',
#  'FLOORSMAX_MEDI',
#  'FLOORSMIN_MEDI',
#  'LANDAREA_MEDI',
#  'LIVINGAPARTMENTS_MEDI',
#  'LIVINGAREA_MEDI',
# ...

# %%
# Checking Value counts for columns which have very few discrete values to come to a conclusion for relevance
#Fetching records where there is payment difficulty i.e target variable = 1

apld_payDifficulties = apld[apld['TARGET'] == 1]

# %%
# Checking the Contact or WorkAddress related columns value counts against target Variable . 
# Checking for records only where there is payment difficulty i.e target = 1

list_of_columns = ['REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION',
       'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY',
       'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY']



df_finalWorkAdd = pd.DataFrame()
for i in list_of_columns:
    Ucheck = apld_payDifficulties[i].value_counts(normalize=True)
    df_finalWorkAdd.loc[:, i] = Ucheck
    
df_finalWorkAdd
# Out:
#    REG_REGION_NOT_LIVE_REGION  REG_REGION_NOT_WORK_REGION  \
# 0                    0.982558                    0.944089
# 1                    0.017442                    0.055911
#
#    LIVE_REGION_NOT_WORK_REGION  REG_CITY_NOT_LIVE_CITY  \
# 0                     0.957462                0.881611
# 1                     0.042538                0.118389
#
#    REG_CITY_NOT_WORK_CITY  LIVE_CITY_NOT_WORK_CITY
# 0                 0.69708                 0.778328
# 1                 0.30292                 0.221672

# %%
# Based on the above result we can drop the columns 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION' ,
# 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY' as most of the records have same value 

droplist_col.extend(['REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION',
       'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY'])

# %%
# Checking the Id proof/Documents submitted value counts against target Variable . 
# Checking for records only where there is payment difficulty i.e target = 1

DocumentsColumnList  = []
for i in apld_payDifficulties.columns:
    if i.startswith('FLAG_DOCUMENT'):
        DocumentsColumnList.append(i)


df_FinalDocumentFlag = pd.DataFrame()

for i in DocumentsColumnList:
    Ucheck = apld_payDifficulties[i].value_counts(normalize=True)
    df_FinalDocumentFlag.loc[:, i] = Ucheck
    
df_FinalDocumentFlag
# Out:
#    FLAG_DOCUMENT_2  FLAG_DOCUMENT_3  FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  \
# 0         0.999839         0.222075              1.0         0.985015
# 1         0.000161         0.777925              NaN         0.014985
#
#    FLAG_DOCUMENT_6  FLAG_DOCUMENT_7  FLAG_DOCUMENT_8  FLAG_DOCUMENT_9  \
# 0         0.939295         0.999879         0.926042         0.997019
# 1         0.060705         0.000121         0.073958         0.002981
#
#    FLAG_DOCUMENT_10  FLAG_DOCUMENT_11  FLAG_DOCUMENT_12  FLAG_DOCUMENT_13  \
# 0               1.0          0.996979               1.0          0.998792
# 1               NaN          0.003021               NaN          0.001208
#
#    FLAG_DOCUMENT_14  FLAG_DOCUMENT_15  FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  \
# 0          0.998792          0.999557          0.993958          0.999919
# 1          0.001208          0.000443          0.006042          0.000081
#
#    FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21
# ...

# %%
# Based on the above output the Flag Document columns can be dropped as 
# almost all the FlagDocumentscolumns have value as 0 for nearly 99% of data. There is one column FLAG_DOCUMENT_3, which
# contradicts but as per the dictionary also, there is no clear information about the type of documents.

droplist_col.extend(DocumentsColumnList)

# %%
# Checking the Contact Details  value counts against target Variable . 
# Checking for records only where there is payment difficulty i.e target = 1

ContactFlagColumnsList = ['FLAG_EMP_PHONE','FLAG_WORK_PHONE','FLAG_CONT_MOBILE','FLAG_PHONE','FLAG_EMAIL']

df_FinalContactFlag = pd.DataFrame()

for i in ContactFlagColumnsList:
    Ucheck = apld_payDifficulties[i].value_counts(normalize=True)
    df_FinalContactFlag.loc[:, i] = Ucheck
    
df_FinalContactFlag
# Out:
#    FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL
# 1        0.879517         0.237825          0.998187    0.244955    0.055347
# 0        0.120483         0.762175          0.001813    0.755045    0.944653

# %%
# Based on above output Flag_Emp_Phone,FLAG_MOBIL,Flag_Cont_Mobile Can be dropped as the majority have the values as 1

droplist_col.extend(['FLAG_EMP_PHONE','FLAG_MOBIL','FLAG_CONT_MOBILE'])

# %%
apld_payDifficulties['FLAG_MOBIL'].value_counts(normalize=True)
# Out:
# 1    1.0
# Name: FLAG_MOBIL, dtype: float64

# %%
# Checking the drop list variable

droplist_col
# Out:
# ['OWN_CAR_AGE',
#  'EXT_SOURCE_1',
#  'APARTMENTS_AVG',
#  'BASEMENTAREA_AVG',
#  'YEARS_BEGINEXPLUATATION_AVG',
#  'YEARS_BUILD_AVG',
#  'COMMONAREA_AVG',
#  'ELEVATORS_AVG',
#  'ENTRANCES_AVG',
#  'FLOORSMAX_AVG',
#  'FLOORSMIN_AVG',
#  'LANDAREA_AVG',
#  'LIVINGAPARTMENTS_AVG',
#  'LIVINGAREA_AVG',
#  'NONLIVINGAPARTMENTS_AVG',
#  'NONLIVINGAREA_AVG',
#  'APARTMENTS_MODE',
#  'BASEMENTAREA_MODE',
#  'YEARS_BEGINEXPLUATATION_MODE',
#  'YEARS_BUILD_MODE',
#  'COMMONAREA_MODE',
#  'ELEVATORS_MODE',
#  'ENTRANCES_MODE',
#  'FLOORSMAX_MODE',
#  'FLOORSMIN_MODE',
#  'LANDAREA_MODE',
#  'LIVINGAPARTMENTS_MODE',
#  'LIVINGAREA_MODE',
#  'NONLIVINGAPARTMENTS_MODE',
#  'NONLIVINGAREA_MODE',
#  'APARTMENTS_MEDI',
#  'BASEMENTAREA_MEDI',
#  'YEARS_BEGINEXPLUATATION_MEDI',
#  'YEARS_BUILD_MEDI',
#  'COMMONAREA_MEDI',
#  'ELEVATORS_MEDI',
#  'ENTRANCES_MEDI',
#  'FLOORSMAX_MEDI',
#  'FLOORSMIN_MEDI',
#  'LANDAREA_MEDI',
#  'LIVINGAPARTMENTS_MEDI',
#  'LIVINGAREA_MEDI',
# ...

# %%
# Copying current application data to new dataframe.

BankLoan_data = apld.copy()

# %%
# checking the shape of dataframe

BankLoan_data.shape
# Out:
# (307511, 122)

# %%
# Dropping the unnecessary columns from the dataframe

BankLoan_data.drop(columns=droplist_col,axis=1,inplace=True)

# %%
# checking the shape of dataframe

BankLoan_data.shape
# Out:
# (307511, 40)

# %%
# Again Checking the null % of columns

# pd.options.display.max_rows = None
round((BankLoan_data.isnull().sum()/BankLoan_data.index.size)*100,2).sort_values(ascending=False)
# Out:
# OCCUPATION_TYPE                31.35
# EXT_SOURCE_3                   19.83
# NAME_TYPE_SUITE                 0.42
# DEF_60_CNT_SOCIAL_CIRCLE        0.33
# OBS_60_CNT_SOCIAL_CIRCLE        0.33
# DEF_30_CNT_SOCIAL_CIRCLE        0.33
# OBS_30_CNT_SOCIAL_CIRCLE        0.33
# EXT_SOURCE_2                    0.21
# AMT_GOODS_PRICE                 0.09
# WEEKDAY_APPR_PROCESS_START      0.00
# FLAG_EMAIL                      0.00
# CNT_FAM_MEMBERS                 0.00
# REGION_RATING_CLIENT            0.00
# REGION_RATING_CLIENT_W_CITY     0.00
# SK_ID_CURR                      0.00
# HOUR_APPR_PROCESS_START         0.00
# REG_CITY_NOT_WORK_CITY          0.00
# FLAG_WORK_PHONE                 0.00
# LIVE_CITY_NOT_WORK_CITY         0.00
# ORGANIZATION_TYPE               0.00
# FLAG_PHONE                      0.00
# DAYS_ID_PUBLISH                 0.00
# TARGET                          0.00
# DAYS_REGISTRATION               0.00
# NAME_CONTRACT_TYPE              0.00
# ...

# %% [markdown]
# #### Get the total count of null values for respective columns in dataframe & taking appropriate actions respectively.

# %%
## Get the total count of null values for AMT_ANNUITY.

BankLoan_data['AMT_ANNUITY'].isnull().sum()
# Out:
# 12

# %%
#### As the number of Records having Annuity Amount as null is very minimal
#### i.e 12 records of entire data set we can replace with median or we could have left it as it is because it won't have much impact due to low frequency.

BankLoan_data['AMT_ANNUITY'].fillna(BankLoan_data['AMT_ANNUITY'].median(), inplace=True)

# %%
# Get the total count of null values in CNT_FAM_MEMBERS.

BankLoan_data.CNT_FAM_MEMBERS.isnull().sum()
# Out:
# 2

# %%
# Checking the value counts for CNT_FAM_MEMBERS

BankLoan_data['CNT_FAM_MEMBERS'].value_counts()
# Out:
# 2.0     158357
# 1.0      67847
# 3.0      52601
# 4.0      24697
# 5.0       3478
# 6.0        408
# 7.0         81
# 8.0         20
# 9.0          6
# 10.0         3
# 14.0         2
# 12.0         2
# 20.0         2
# 16.0         2
# 13.0         1
# 15.0         1
# 11.0         1
# Name: CNT_FAM_MEMBERS, dtype: int64

# %%
# Replacing null values in Count of Family Members Column with Median Value or we could have left it as it is because it won't have much impact due to low frequency.

BankLoan_data['CNT_FAM_MEMBERS'].fillna(BankLoan_data['CNT_FAM_MEMBERS'].median(), inplace=True)

# %%
# re-verifying the total sum of null values within a column

BankLoan_data.CNT_FAM_MEMBERS.isnull().sum()
# Out:
# 0

# %%
# checking the data type of column

BankLoan_data.CNT_FAM_MEMBERS.dtypes
# Out:
# dtype('float64')

# %%
# Converting the column to INT data type

BankLoan_data['CNT_FAM_MEMBERS'] = BankLoan_data['CNT_FAM_MEMBERS'].astype(int)

# %%
# Get the total count of null values for respective column in dataframe

BankLoan_data['AMT_GOODS_PRICE'].isnull().sum()
# Out:
# 278

# %%
# Checking the % of null values

BankLoan_data['AMT_GOODS_PRICE'].isnull().sum()/BankLoan_data.shape[0]
# Out:
# 0.0009040327012692228

# %%
#### As the number of Records having Goods Price Amount as null is very minimal 
#### we can replace with median or we could have left it as it is because it won't have much impact due to low frequency.

BankLoan_data['AMT_GOODS_PRICE'].fillna(BankLoan_data['AMT_GOODS_PRICE'].median(), inplace=True)

# %%
# Re-verifying the total sum of null values

BankLoan_data['AMT_GOODS_PRICE'].isnull().sum()
# Out:
# 0

# %%
# Checking the total count of null values in NAME_TYPE_SUITE.

BankLoan_data.NAME_TYPE_SUITE.isnull().sum()
# Out:
# 1292

# %%
#  Get the value counts of NAME_TYPE_SUITE.

BankLoan_data.NAME_TYPE_SUITE.value_counts()
# Out:
# Unaccompanied      248526
# Family              40149
# Spouse, partner     11370
# Children             3267
# Other_B              1770
# Other_A               866
# Group of people       271
# Name: NAME_TYPE_SUITE, dtype: int64

# %%
# Get the mode of NAME_TYPE_SUITE.

BankLoan_data.NAME_TYPE_SUITE.mode()[0]
# Out:
# 'Unaccompanied'

# %%
# Filling Na values is NAME_TYPE_SUITE with mode

BankLoan_data.NAME_TYPE_SUITE.fillna(BankLoan_data.NAME_TYPE_SUITE.mode()[0], inplace=True)

# %%
# Re-verifying the total null value count of NAME_TYPE_SUITE.

BankLoan_data.NAME_TYPE_SUITE.isnull().sum()
# Out:
# 0

# %%
# Checking the % of null values count for the columns in dataframe

round((BankLoan_data.isnull().sum()/BankLoan_data.index.size)*100,2).sort_values(ascending=False)
# Out:
# OCCUPATION_TYPE                31.35
# EXT_SOURCE_3                   19.83
# DEF_60_CNT_SOCIAL_CIRCLE        0.33
# OBS_60_CNT_SOCIAL_CIRCLE        0.33
# DEF_30_CNT_SOCIAL_CIRCLE        0.33
# OBS_30_CNT_SOCIAL_CIRCLE        0.33
# EXT_SOURCE_2                    0.21
# SK_ID_CURR                      0.00
# REGION_RATING_CLIENT_W_CITY     0.00
# FLAG_PHONE                      0.00
# FLAG_EMAIL                      0.00
# CNT_FAM_MEMBERS                 0.00
# REGION_RATING_CLIENT            0.00
# REG_CITY_NOT_WORK_CITY          0.00
# WEEKDAY_APPR_PROCESS_START      0.00
# HOUR_APPR_PROCESS_START         0.00
# TARGET                          0.00
# LIVE_CITY_NOT_WORK_CITY         0.00
# ORGANIZATION_TYPE               0.00
# FLAG_WORK_PHONE                 0.00
# DAYS_ID_PUBLISH                 0.00
# DAYS_REGISTRATION               0.00
# AMT_ANNUITY                     0.00
# NAME_CONTRACT_TYPE              0.00
# CODE_GENDER                     0.00
# ...

# %%
# Checking for Columns Which have values as XNA .
# At CODE_GENDER,here Gender Can be either Male or Female . 
# 4 records have value as XNA . As the mode is Female we can replace those 4 records value as F
# there wont be much impact or we could have left it as it is because it won't have much impact.

BankLoan_data.CODE_GENDER.value_counts()
# Out:
# F      202448
# M      105059
# XNA         4
# Name: CODE_GENDER, dtype: int64

# %%
# Replacing the XNA values with F

BankLoan_data['CODE_GENDER'].replace('XNA','F', inplace=True)

# %%
# We can observe now the XNA values are replaced

BankLoan_data.CODE_GENDER.value_counts()
# Out:
# F    202452
# M    105059
# Name: CODE_GENDER, dtype: int64

# %%
# Checking the value counts of FLAG_OWN_REALTY.

BankLoan_data['FLAG_OWN_REALTY'].value_counts()
# Out:
# Y    213312
# N     94199
# Name: FLAG_OWN_REALTY, dtype: int64

# %%
# Checking the value counts of FLAG_OWN_REALTY.

BankLoan_data['FLAG_OWN_CAR'].value_counts()
# Out:
# N    202924
# Y    104587
# Name: FLAG_OWN_CAR, dtype: int64

# %%
# Family Status of the Client Correction of Few Records. 2 Records have value Unknown
# This can be replaced by Mode value i.e Married. It wouldnt affect the analysis.

BankLoan_data.NAME_FAMILY_STATUS.value_counts()
# Out:
# Married                 196432
# Single / not married     45444
# Civil marriage           29775
# Separated                19770
# Widow                    16088
# Unknown                      2
# Name: NAME_FAMILY_STATUS, dtype: int64

# %%
# Checking the mode of the column NAME_FAMILY_STATUS.

BankLoan_data.NAME_FAMILY_STATUS.mode()[0]
# Out:
# 'Married'

# %%
# Replacing the value of column NAME_FAMILY_STATUS.

BankLoan_data['NAME_FAMILY_STATUS'].replace('Unknown',BankLoan_data.NAME_FAMILY_STATUS.mode()[0], inplace=True)

# %%
# Now Recheck the Data if the records are cleansed

BankLoan_data.NAME_FAMILY_STATUS.value_counts()
# Out:
# Married                 196434
# Single / not married     45444
# Civil marriage           29775
# Separated                19770
# Widow                    16088
# Name: NAME_FAMILY_STATUS, dtype: int64

# %%
# Checking the value counts of OCCUPATION_TYPE

BankLoan_data['OCCUPATION_TYPE'].value_counts()
# Out:
# Laborers                 55186
# Sales staff              32102
# Core staff               27570
# Managers                 21371
# Drivers                  18603
# High skill tech staff    11380
# Accountants               9813
# Medicine staff            8537
# Security staff            6721
# Cooking staff             5946
# Cleaning staff            4653
# Private service staff     2652
# Low-skill Laborers        2093
# Waiters/barmen staff      1348
# Secretaries               1305
# Realty agents              751
# HR staff                   563
# IT staff                   526
# Name: OCCUPATION_TYPE, dtype: int64

# %%
# Getting the count of null values in OCCUPATION_TYPE.

BankLoan_data.OCCUPATION_TYPE.isnull().sum()
# Out:
# 96391

# %%
# There are huge data having Occupation type as null, we cannot impute with the mode of this category as 
# it would lead us to a biased decision.So filling all na values in occupation type as Unknown.

BankLoan_data.OCCUPATION_TYPE.fillna('Unknown', inplace=True)

# %%
#  Get the value counts of OCCUPATION_TYPE.

BankLoan_data.OCCUPATION_TYPE.value_counts()
# Out:
# Unknown                  96391
# Laborers                 55186
# Sales staff              32102
# Core staff               27570
# Managers                 21371
# Drivers                  18603
# High skill tech staff    11380
# Accountants               9813
# Medicine staff            8537
# Security staff            6721
# Cooking staff             5946
# Cleaning staff            4653
# Private service staff     2652
# Low-skill Laborers        2093
# Waiters/barmen staff      1348
# Secretaries               1305
# Realty agents              751
# HR staff                   563
# IT staff                   526
# Name: OCCUPATION_TYPE, dtype: int64

# %%
# Checking the null % of all columns in a dataframe again.

round((BankLoan_data.isnull().sum()/BankLoan_data.index.size)*100,2).sort_values(ascending=False)
# Out:
# EXT_SOURCE_3                   19.83
# DEF_60_CNT_SOCIAL_CIRCLE        0.33
# OBS_60_CNT_SOCIAL_CIRCLE        0.33
# DEF_30_CNT_SOCIAL_CIRCLE        0.33
# OBS_30_CNT_SOCIAL_CIRCLE        0.33
# EXT_SOURCE_2                    0.21
# SK_ID_CURR                      0.00
# REGION_RATING_CLIENT_W_CITY     0.00
# FLAG_PHONE                      0.00
# FLAG_EMAIL                      0.00
# OCCUPATION_TYPE                 0.00
# CNT_FAM_MEMBERS                 0.00
# REGION_RATING_CLIENT            0.00
# REG_CITY_NOT_WORK_CITY          0.00
# WEEKDAY_APPR_PROCESS_START      0.00
# HOUR_APPR_PROCESS_START         0.00
# TARGET                          0.00
# LIVE_CITY_NOT_WORK_CITY         0.00
# ORGANIZATION_TYPE               0.00
# FLAG_WORK_PHONE                 0.00
# DAYS_ID_PUBLISH                 0.00
# DAYS_REGISTRATION               0.00
# AMT_ANNUITY                     0.00
# NAME_CONTRACT_TYPE              0.00
# CODE_GENDER                     0.00
# ...

# %%
# dropping few more columns as seems irrelevant for analysis

BankLoan_data.drop(columns=['OBS_30_CNT_SOCIAL_CIRCLE','DEF_30_CNT_SOCIAL_CIRCLE','OBS_60_CNT_SOCIAL_CIRCLE',
                           'DEF_60_CNT_SOCIAL_CIRCLE','DAYS_LAST_PHONE_CHANGE'], inplace=True)

# %%
# we can drop EXT_SOURCE_2 and EXT_SOURCE_3 columns as well because we dont have any clear metadata as what its refering to.

BankLoan_data.drop(columns=['EXT_SOURCE_2','EXT_SOURCE_3'], inplace=True)

# %%
# Checking the null % of columns in a dataframe

round((BankLoan_data.isnull().sum()/BankLoan_data.index.size)*100,2).sort_values(ascending=False)
# Out:
# SK_ID_CURR                     0.0
# DAYS_BIRTH                     0.0
# LIVE_CITY_NOT_WORK_CITY        0.0
# REG_CITY_NOT_WORK_CITY         0.0
# HOUR_APPR_PROCESS_START        0.0
# WEEKDAY_APPR_PROCESS_START     0.0
# REGION_RATING_CLIENT_W_CITY    0.0
# REGION_RATING_CLIENT           0.0
# CNT_FAM_MEMBERS                0.0
# OCCUPATION_TYPE                0.0
# FLAG_EMAIL                     0.0
# FLAG_PHONE                     0.0
# FLAG_WORK_PHONE                0.0
# DAYS_ID_PUBLISH                0.0
# DAYS_REGISTRATION              0.0
# DAYS_EMPLOYED                  0.0
# REGION_POPULATION_RELATIVE     0.0
# TARGET                         0.0
# NAME_HOUSING_TYPE              0.0
# NAME_FAMILY_STATUS             0.0
# NAME_EDUCATION_TYPE            0.0
# NAME_INCOME_TYPE               0.0
# NAME_TYPE_SUITE                0.0
# AMT_GOODS_PRICE                0.0
# AMT_ANNUITY                    0.0
# AMT_CREDIT                     0.0
# AMT_INCOME_TOTAL               0.0
# ...

# %%
# Checking the shape of the dataframe

BankLoan_data.shape
# Out:
# (307511, 33)

# %%
# Numerical Columns Available in BankLoan_data dataframe

num_col = BankLoan_data.describe().columns

# %%
# Creating an Age Column based on Days_Birth & taking care of '-' sign

BankLoan_data['Age'] = abs(round((BankLoan_data['DAYS_BIRTH'].replace('-',''))/365,2)).astype(int)

# %%
# Creating Age Group Buckets for easy analysis.

BankLoan_data['Age_Group'] = pd.cut(x=BankLoan_data['Age'], bins=[20, 30, 40, 50, 60, 70], labels=['20 to 30', '31 to 40', '41 to 50', '51 to 60', '61 to 70'])

# %%
BankLoan_data.Age_Group.dtype
# Out:
# CategoricalDtype(categories=['20 to 30', '31 to 40', '41 to 50', '51 to 60', '61 to 70'], ordered=True)

# %%
# Get the top 5 records of new dataframe

BankLoan_data.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#    AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 0         351000.0   Unaccompanied          Working
# ...

# %%
# convert the days employed to years and apply absolute function as it is in negative form

BankLoan_data['YearsWorked'] = abs(round((BankLoan_data['DAYS_EMPLOYED'].replace('-',''))/365,2)).astype(int)

# %%
BankLoan_data['YearsWorked'].value_counts(normalize=True)
# Out:
# 1000    0.180072
# 1       0.103541
# 2       0.096390
# 0       0.090572
# 3       0.081626
# 4       0.070814
# 5       0.052961
# 6       0.048922
# 7       0.042805
# 8       0.037238
# 9       0.029183
# 10      0.023970
# 11      0.019199
# 12      0.017277
# 14      0.015125
# 13      0.014130
# 15      0.008891
# 16      0.007577
# 17      0.006536
# 18      0.006231
# 19      0.006084
# 20      0.005210
# 21      0.004754
# 22      0.004071
# 23      0.003314
# 24      0.002976
# 25      0.002670
# 27      0.002133
# 26      0.002124
# 28      0.001980
# 29      0.001847
# 30      0.001489
# 31      0.001418
# 34      0.001187
# 32      0.001141
# 33      0.001076
# 35      0.000832
# 36      0.000637
# 37      0.000452
# 39      0.000406
# 38      0.000377
# 40      0.000192
# 41      0.000192
# 42      0.000137
# 44      0.000098
# 43      0.000062
# 45      0.000049
# 48      0.000013
# 46      0.000013
# 47      0.000003
# 49      0.000003
# ...

# %%
# Clearly we can see there is 1 outlier with years worked as 1000 which is erroneous
# We can replace this value with 1 as clearly a person cant work for 1000 years

BankLoan_data['YearsWorked'] = BankLoan_data['YearsWorked'].replace(1000,1)

# %%
BankLoan_data.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#    AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 0         351000.0   Unaccompanied          Working
# ...

# %%
# Category Object Columns Available in BankLoan_data Dataframe,which will be further used for analysis.
category_colms = BankLoan_data.select_dtypes(include=['object']).columns
category_colms
# Out:
# Index(['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE',
#        'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE'],
#       dtype='object')

# %%
BankLoan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   SK_ID_CURR                   307511 non-null  int64
#  1   TARGET                       307511 non-null  int64
#  2   NAME_CONTRACT_TYPE           307511 non-null  object
#  3   CODE_GENDER                  307511 non-null  object
#  4   FLAG_OWN_CAR                 307511 non-null  object
#  5   FLAG_OWN_REALTY              307511 non-null  object
#  6   CNT_CHILDREN                 307511 non-null  int64
#  7   AMT_INCOME_TOTAL             307511 non-null  float64
#  8   AMT_CREDIT                   307511 non-null  float64
#  9   AMT_ANNUITY                  307511 non-null  float64
#  10  AMT_GOODS_PRICE              307511 non-null  float64
#  11  NAME_TYPE_SUITE              307511 non-null  object
# ...

# %% [markdown]
# ### Data Imbalance

# %%
# checking for data imbalance

BankLoan_data.TARGET.value_counts(normalize=True)*100
# Out:
# 0    91.927118
# 1     8.072882
# Name: TARGET, dtype: float64

# %%
# As majority of data of data belong to Target 0 and very less to Target 1, it depicts that there is a data imbalance.
# Calculating data imbalance ratio:

round(len(BankLoan_data[BankLoan_data.TARGET==0]) / len(BankLoan_data[BankLoan_data.TARGET==1]),2)
# Out:
# 11.39

# %%
# Plotting Pie Chart with pop up.
x = ['Defaulter(TARGET=1)','Non-Defauter(TARGET=0)']
y = [len(BankLoan_data[BankLoan_data.TARGET==1]), len(BankLoan_data[BankLoan_data.TARGET==0])]
plt.pie(y, data=BankLoan_data.TARGET, labels=x, autopct='%1.1f%%', shadow=True, explode= (0.1, 0))
plt.title('Data imbalance- Pie Chart',fontdict={'fontsize':20})
plt.show()

# %%
# Dividing the dataset for target=1(client with payment difficulties) and target=0(all other)

BankLoan_data_Target0=BankLoan_data.loc[BankLoan_data["TARGET"]==0]
BankLoan_data_Target1=BankLoan_data.loc[BankLoan_data["TARGET"]==1]

# %% [markdown]
# ### Univariate Analysis of Categorical columns

# %%
##### Creating a user defined function which is used for all Categorical Variable Analysis

def plot_func(dataframe,dim):
    fig = plt.figure(figsize=(14,11))
    ax1 = plt.subplot(221)
    dataframe[dim].value_counts().plot.pie(autopct = "%1.0f%%" , ax = ax1)
    plt.title("Plotting data for the category " + dim)
    ax2 = plt.subplot(222)
    sns.countplot(x=dim,hue='TARGET',data=dataframe,ax=ax2)
    plt.xticks(rotation=90)
    plt.title("Plotting data for target in terms of total count")
    ax3 = plt.subplot(223)
    df=pd.DataFrame()
    df['0'] = ((BankLoan_data_Target0[dim].value_counts())/len(BankLoan_data_Target0))
    df['1'] = ((BankLoan_data_Target1[dim].value_counts())/len(BankLoan_data_Target1))
    df.plot.bar(ax=ax3)
    plt.title("Plotting data in terms of percentage")
    fig.tight_layout()
    plt.show()

# %%
for col in category_colms:
    print('>>>>>>>>>>>>>>> Plot for ',col,' <<<<<<<<<<<<<<<')
    plot_func(BankLoan_data,col)
# Out:
# >>>>>>>>>>>>>>> Plot for  NAME_CONTRACT_TYPE  <<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>> Plot for  CODE_GENDER  <<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>> Plot for  FLAG_OWN_CAR  <<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>> Plot for  FLAG_OWN_REALTY  <<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>> Plot for  NAME_TYPE_SUITE  <<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>> Plot for  NAME_INCOME_TYPE  <<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>> Plot for  NAME_EDUCATION_TYPE  <<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>> Plot for  NAME_FAMILY_STATUS  <<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>> Plot for  NAME_HOUSING_TYPE  <<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>> Plot for  OCCUPATION_TYPE  <<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>> Plot for  WEEKDAY_APPR_PROCESS_START  <<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>> Plot for  ORGANIZATION_TYPE  <<<<<<<<<<<<<<<

# %% [markdown]
# #### Individual Analysis

# %%
plot_func(BankLoan_data,'NAME_CONTRACT_TYPE')

# %% [markdown]
# - Bank is primarily providing 2 types of loans : Cash & Revolving . Majority of the loans given are cash loans.
# Comparatively Cash loans taken by clients are facing bit more difficulties than revolving loans

# %%
plot_func(BankLoan_data,'CODE_GENDER')

# %% [markdown]
# - Percentage of loan given to females are more than males. Males are having more difficulties paying back the loan as compared to Females.

# %%
plot_func(BankLoan_data,'NAME_INCOME_TYPE')

# %% [markdown]
# - According to the above graphs we can infer that Working people category have more difficulty in paying back loan & thus should be carefully given loan.

# %%
plot_func(BankLoan_data,'NAME_HOUSING_TYPE')

# %% [markdown]
# - Clients living with parents are facing more difficulties in repaying the loan. Probably their medical/other expenses are more.

# %%
plot_func(BankLoan_data,'FLAG_OWN_CAR')

# %% [markdown]
# - People owning car find it less difficulty in repaying loan.

# %%
plot_func(BankLoan_data,'FLAG_OWN_REALTY')

# %% [markdown]
# - According to above graphs clients that already possess a car/real estate property are having comparatively less difficulties in paying back loan.
# - We can infer that they may be already in a good financial position and are able to pay the instalments on time

# %%
plot_func(BankLoan_data,'NAME_EDUCATION_TYPE')

# %% [markdown]
# - People with Higher Education find it less difficult to repay their loan may be due to their better paying jobs than that of people having lesser level of education like Secondary/Secondary special.

# %%
plot_func(BankLoan_data,'NAME_FAMILY_STATUS')

# %% [markdown]
# - Married people are finding it easier to repay loans than Single/not married people, may be due to their better finacial stability & management or both partners may be having earning source.
# - Widowed people are also finding it less difficulty in repaying,may be due to them having less extravagant life style.

# %%
#### Plotting for Age Group:
plot_func(BankLoan_data,'Age_Group')

# %% [markdown]
# - People above 40 are facing less difficulty in repaying loans,may be due to better paying jobs & better maturity in Financial management.
# - Young People between 20-40 find it little difficult to repay the loan,may be due to their lesser paying job or extravagant life style or poor financial management.

# %% [markdown]
# ### Univariate Analysis and Outliers for Numerical columns

# %%
##### Plotting box plots for all numerical columns 
for col in num_col:
    print('Box Plot for ',col)
    plt.figure(figsize=[14,4])
    sns.set(style='whitegrid')
    plt.xscale('log')
    sns.boxplot(data =BankLoan_data, x=col,orient='v')
    plt.show()
    print()
# Out:
# Box Plot for  SK_ID_CURR
# Box Plot for  TARGET
# Box Plot for  CNT_CHILDREN
# Box Plot for  AMT_INCOME_TOTAL
# Box Plot for  AMT_CREDIT
# Box Plot for  AMT_ANNUITY
# Box Plot for  AMT_GOODS_PRICE
# Box Plot for  REGION_POPULATION_RELATIVE
# Box Plot for  DAYS_BIRTH
# Box Plot for  DAYS_EMPLOYED
# Box Plot for  DAYS_REGISTRATION
# Box Plot for  DAYS_ID_PUBLISH
# Box Plot for  FLAG_WORK_PHONE
# Box Plot for  FLAG_PHONE
# Box Plot for  FLAG_EMAIL
# Box Plot for  CNT_FAM_MEMBERS
# Box Plot for  REGION_RATING_CLIENT
# Box Plot for  REGION_RATING_CLIENT_W_CITY
# Box Plot for  HOUR_APPR_PROCESS_START
# Box Plot for  REG_CITY_NOT_WORK_CITY
# Box Plot for  LIVE_CITY_NOT_WORK_CITY

# %% [markdown]
# - CNT_CHILDREN, AMT_INCOME_TOTAL, AMT_CREDIT, AMT_ANNUITY, AMT_GOODS_PRICE ,DAYS_EMPLOYED are few columns which has outliers. Above box plot shows few data points which are outside the Interquartile region.

# %%
#### Correcting the outliers in data 
#### Anything above 1.5 * 75 percentile Can be considered as a suspected outlier

outlier = np.percentile(BankLoan_data.AMT_INCOME_TOTAL,75) * 1.5

#### Fetching data less than outlier into another dataframe

BankLoan_data_income_corrected = BankLoan_data[BankLoan_data['AMT_INCOME_TOTAL'] < outlier]
BankLoan_data_income_correctedTarget1 = BankLoan_data_income_corrected[BankLoan_data_income_corrected['TARGET'] == 1]

# %%
######Plotting the data to see the Income Range of Defaulters
plt.figure(figsize=[14,4])
plt.subplot(1,2,1)
sns.boxplot(BankLoan_data_income_correctedTarget1['AMT_INCOME_TOTAL'],orient='v')
plt.subplot(1,2,2)
plt.hist(x=BankLoan_data_income_correctedTarget1['AMT_INCOME_TOTAL']);
plt.show()

# %% [markdown]
# ###### clients having income between 100000 to 150000 are the segment with more clients facing payment difficulties

# %%
#### Correcting the outliers in data for Credit Amount 
#### Anything above 1.5 * 75 percentile Can be considered as a suspected outlier

outlier_creditAmt = np.percentile(BankLoan_data.AMT_CREDIT,75) * 1.5

#### Fetching data less than outlier into another dataframe

BankLoan_data_creditAmt_corrected = BankLoan_data[BankLoan_data['AMT_CREDIT'] < outlier_creditAmt]
BankLoan_data_creditAmt_correctedTarget1 = BankLoan_data_creditAmt_corrected[BankLoan_data_creditAmt_corrected['TARGET'] == 1]

# %%
#### Plotting the data to see the Loan Amt for defaulters
######Plotting the data to see the Income Range of Defaulters
plt.figure(figsize=[14,4])
plt.subplot(1,2,1)
sns.boxplot(BankLoan_data_creditAmt_correctedTarget1['AMT_CREDIT'],orient='v')
plt.subplot(1,2,2)
plt.hist(x=BankLoan_data_creditAmt_correctedTarget1['AMT_CREDIT']);
plt.show()

# %%
BankLoan_data_Target1[(BankLoan_data_Target1['AMT_CREDIT'] > 200000) & (BankLoan_data_Target1['AMT_CREDIT'] < 600000) ].shape[0]/BankLoan_data_Target1.shape[0]
# Out:
# 0.5493655589123867

# %% [markdown]
# - Around 55 % of the population have Amount credit ranges from 2 lakh to 6 lakh

# %%
##### Checking for Children Count column : 
BankLoan_data['CNT_CHILDREN'].value_counts(normalize=True)
# Out:
# 0     0.700368
# 1     0.198754
# 2     0.086986
# 3     0.012087
# 4     0.001395
# 5     0.000273
# 6     0.000068
# 7     0.000023
# 14    0.000010
# 8     0.000007
# 9     0.000007
# 12    0.000007
# 10    0.000007
# 19    0.000007
# 11    0.000003
# Name: CNT_CHILDREN, dtype: float64

# %%
###### More than 99 % of the data has less than 5 children 
BankLoan_data[BankLoan_data['CNT_CHILDREN'] > 5].shape[0]
# Out:
# 42

# %%
#### For better analysis We will consider the loan dataset with less than 5 children into a subset dataframe

BankLoan_data[BankLoan_data['CNT_CHILDREN'] > 5].shape[0]/BankLoan_data.shape[0]
BankLoan_data_byChildren = BankLoan_data[BankLoan_data['CNT_CHILDREN'] < 5]

# %%
#### Plots wrt. number of Children:
plot_func(BankLoan_data,'CNT_CHILDREN')

# %% [markdown]
# - People with no children have low chance to default.
# - But as the number of children increases,people have increased difficulty in repaying the loan.

# %%
#### Checking outliers for number of Years Employed.
BankLoan_data['YearsWorked'].value_counts(normalize=True)
# Out:
# 1     0.283613
# 2     0.096390
# 0     0.090572
# 3     0.081626
# 4     0.070814
# 5     0.052961
# 6     0.048922
# 7     0.042805
# 8     0.037238
# 9     0.029183
# 10    0.023970
# 11    0.019199
# 12    0.017277
# 14    0.015125
# 13    0.014130
# 15    0.008891
# 16    0.007577
# 17    0.006536
# 18    0.006231
# 19    0.006084
# 20    0.005210
# 21    0.004754
# 22    0.004071
# 23    0.003314
# 24    0.002976
# 25    0.002670
# 27    0.002133
# 26    0.002124
# 28    0.001980
# 29    0.001847
# 30    0.001489
# 31    0.001418
# 34    0.001187
# 32    0.001141
# 33    0.001076
# 35    0.000832
# 36    0.000637
# 37    0.000452
# 39    0.000406
# 38    0.000377
# 40    0.000192
# 41    0.000192
# 42    0.000137
# 44    0.000098
# 43    0.000062
# 45    0.000049
# 48    0.000013
# 46    0.000013
# 47    0.000003
# 49    0.000003
# Name: YearsWorked, dtype: float64

# %%
BankLoan_data_Target1['YearsWorked'].value_counts(normalize=True)
# Out:
# 1     0.266667
# 2     0.127895
# 0     0.123303
# 3     0.102598
# 4     0.080040
# 5     0.053454
# 6     0.046485
# 7     0.038550
# 8     0.031581
# 9     0.022840
# 10    0.018812
# 11    0.013535
# 12    0.011722
# 14    0.010352
# 13    0.009789
# 15    0.005398
# 16    0.004512
# 17    0.003988
# 18    0.003746
# 19    0.003545
# 21    0.002981
# 20    0.002699
# 22    0.002216
# 23    0.002095
# 24    0.001974
# 25    0.001611
# 28    0.001249
# 29    0.001128
# 30    0.000886
# 32    0.000765
# 26    0.000725
# 27    0.000604
# 31    0.000604
# 34    0.000483
# 33    0.000483
# 35    0.000242
# 39    0.000161
# 36    0.000121
# 38    0.000081
# 37    0.000040
# 44    0.000040
# Name: YearsWorked, dtype: float64

# %%
BankLoan_data_Target0.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
# 5      100008       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
# 5               Y             0           99000.0    490495.5      27517.5
#
#    AMT_GOODS_PRICE  NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 1        1129500.0           Family    State servant
# ...

# %%
BankLoan_data_Target0.shape
# Out:
# (282686, 36)

# %%
BankLoan_data_Target1.shape
# Out:
# (24825, 36)

# %%
#### Plotting the data to see the Years of Employment for Dafaulters and NonDefaulters
plt.figure(figsize=[14,4])
plt.subplot(1,2,1)
plt.title("Histogram: Years of Employment - Non Dafaulters")
plt.hist(x=BankLoan_data_Target0['YearsWorked']);
plt.subplot(1,2,2)
plt.title("Histogram: Years of Employment - Dafaulters")
plt.hist(x=BankLoan_data_Target1['YearsWorked']);
plt.show()

# %%
##### As the number of clients > 10 years is less. Considering only < 10 years client.
df_YearsEmployed=pd.DataFrame()
df_YearsEmployed['0'] = ((BankLoan_data_Target0['YearsWorked'].value_counts())/len(BankLoan_data_Target0))
df_YearsEmployed['1'] = ((BankLoan_data_Target1['YearsWorked'].value_counts())/len(BankLoan_data_Target1))
df_YearsEmployed.plot(kind='bar',figsize=(16,8))
plt.title('Bar plot for Years worked (Target 0 and 1)', fontdict={'fontsize':20})
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - We can infer that people in the early stage of their career i.e experience between 1 -5 years face paying difficulties more.
# - And the experienced people i.e. experience of more than 5 years, get well settled with good salary dont face much paying difficulties.

# %% [markdown]
# ### Bivariate Analysis

# %%
# Bivariate Analysis

plt.figure(figsize=(14,10))
plt.xticks(rotation=45)
plt.ticklabel_format(style = 'plain')
plt.yscale('log')
sns.boxplot(data =BankLoan_data_Target0, x='NAME_EDUCATION_TYPE',y='AMT_INCOME_TOTAL', hue ='NAME_FAMILY_STATUS',orient='v')
plt.title('AMT_INCOME_TOTAL vs NAME_EDUCATION_TYPE (TARGET 0)')
plt.show()

# %% [markdown]
# - For non defaulters : Education Type with Higher education and 'Secondary/secondary special' Amount income total is mostly equal among the family status. These two education type has many outliers as well.
# - Academic degree education type have less outliers and also their amount income total seems to be little on higher side.

# %%
plt.figure(figsize=(14,10))
plt.xticks(rotation=45)
plt.ticklabel_format(style = 'plain')
plt.yscale('log')
sns.boxplot(data =BankLoan_data_Target1, x='NAME_EDUCATION_TYPE',y='AMT_INCOME_TOTAL', hue ='NAME_FAMILY_STATUS',orient='v')
plt.title('AMT_INCOME_TOTAL vs NAME_EDUCATION_TYPE (TARGET 1)')
plt.show()

# %% [markdown]
# - For Defaulters : Education Type with 'Secondary/secondary special' and 'Higher education' Amount income total is mostly equal among the family status. These two education type has many outliers as well.
# - Academic degree education type have less outliers and also their amount income total seems to be on higher side.

# %%
plt.figure(figsize=(14,10))
plt.xticks(rotation=45)
plt.ticklabel_format(style = 'plain')
plt.yscale('log')
sns.boxplot(data =BankLoan_data_Target0, x='NAME_EDUCATION_TYPE',y='AMT_CREDIT', hue ='NAME_FAMILY_STATUS',orient='v')
plt.title('AMT_CREDIT vs NAME_EDUCATION_TYPE (TARGET 0)')
plt.show()

# %% [markdown]
# - For Non Defaulters : Academic degree education type have less outliers and also family status of Married, civil marriage and seperated have higher Amount Credits. Whereas, Higher education and Secondary/secondary special group have many outliers.

# %%
plt.figure(figsize=(14,10))
plt.xticks(rotation=45)
plt.ticklabel_format(style = 'plain')
plt.yscale('log')
sns.boxplot(data =BankLoan_data_Target1, x='NAME_EDUCATION_TYPE',y='AMT_CREDIT', hue ='NAME_FAMILY_STATUS',orient='v')
plt.title('AMT_CREDIT vs NAME_EDUCATION_TYPE (TARGET 1)')
plt.show()

# %% [markdown]
# - For Defaulters : Most of the outliers are from Education type 'Secondary/secondary special', 'Incomplete higher' and 'Higher education'. Very few outliers observed for Lower secondary and Academic.
# - Single, civil marriage and seperated family status group has almost similar amount credit under Seondary/secondary special status.

# %%
num_col
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT',
#        'REGION_RATING_CLIENT_W_CITY', 'HOUR_APPR_PROCESS_START',
#        'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY'],
#       dtype='object')

# %%
category_colms
# Out:
# Index(['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE',
#        'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE'],
#       dtype='object')

# %% [markdown]
# ### Correlation

# %%
# Top 10 positive or negative Correlation for target 0 for all numerical columns in loan data

corr0 = BankLoan_data_Target0.corr()
mask0 = np.zeros_like(corr0)
mask0[np.triu_indices_from(mask0)]= True
f, ax = plt.subplots(figsize=(11, 9))
with sns.axes_style('white'):
    ax= sns.heatmap(corr0, mask=mask0, vmax=.3, square=True)
    plt.title('Correlation Heat map (TARGET 0/Non-Defaulters)',fontdict={'fontsize':20})
    plt.show()

# %%
a = BankLoan_data_Target0.corr().abs().unstack().dropna()

# %%
a = a[~(a==1.0)]

# %% [markdown]
# #### Top 10 correlation (positive or negative) for Non-defaulters - Target 0

# %%
round(a.sort_values(kind='quicksort').drop_duplicates().tail(10).sort_values(ascending=False)*100,2)
# Out:
# DAYS_BIRTH                   Age                       99.97
# AMT_CREDIT                   AMT_GOODS_PRICE           98.70
# REGION_RATING_CLIENT_W_CITY  REGION_RATING_CLIENT      95.01
# CNT_FAM_MEMBERS              CNT_CHILDREN              87.86
# LIVE_CITY_NOT_WORK_CITY      REG_CITY_NOT_WORK_CITY    83.04
# AMT_GOODS_PRICE              AMT_ANNUITY               77.64
# AMT_CREDIT                   AMT_ANNUITY               77.13
# DAYS_BIRTH                   DAYS_EMPLOYED             61.80
# DAYS_EMPLOYED                Age                       61.80
# REGION_POPULATION_RELATIVE   REGION_RATING_CLIENT      53.90
# dtype: float64

# %%
# Top 10 positive or negative Correlation for target 1 for all numerical 

corr1 = BankLoan_data_Target1.corr()
mask1 = np.zeros_like(corr1)
mask1[np.triu_indices_from(mask1)]= True
f, ax = plt.subplots(figsize=(11, 9))
with sns.axes_style('white'):
    ax= sns.heatmap(corr1, mask=mask1, vmax=.3, square=True)
    plt.title('Correlation Heat map (TARGET 1/Defaulters)',fontdict={'fontsize':20})
    plt.show()

# %%
b = BankLoan_data_Target1.corr().abs().unstack().dropna()

# %%
b = b[~(b==1.0)]

# %% [markdown]
# #### Top 10 correlation (positive or negative) for Defaulters - Target 1

# %%
round(b.sort_values(kind='quicksort').drop_duplicates().tail(10).sort_values(ascending=False)*100,2)
# Out:
# DAYS_BIRTH                   Age                            99.97
# AMT_CREDIT                   AMT_GOODS_PRICE                98.28
# REGION_RATING_CLIENT_W_CITY  REGION_RATING_CLIENT           95.66
# CNT_FAM_MEMBERS              CNT_CHILDREN                   88.55
# REG_CITY_NOT_WORK_CITY       LIVE_CITY_NOT_WORK_CITY        77.85
# AMT_ANNUITY                  AMT_GOODS_PRICE                75.23
#                              AMT_CREDIT                     75.22
# Age                          DAYS_EMPLOYED                  57.53
# DAYS_BIRTH                   DAYS_EMPLOYED                  57.51
# REGION_POPULATION_RELATIVE   REGION_RATING_CLIENT_W_CITY    44.70
# dtype: float64

# %% [markdown]
# ## Previous Application data analysis

# %%
prev_appl_data = pd.read_csv("previous_application.csv")

# %%
prev_appl_data.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
#    HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  \
# ...

# %%
# Check the number of rows and columns in the dataframe

prev_appl_data.shape
# Out:
# (1670214, 37)

# %%
# Check the column-wise info of the dataframe

prev_appl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1670214 non-null  int64
#  1   SK_ID_CURR                   1670214 non-null  int64
#  2   NAME_CONTRACT_TYPE           1670214 non-null  object
#  3   AMT_ANNUITY                  1297979 non-null  float64
#  4   AMT_APPLICATION              1670214 non-null  float64
#  5   AMT_CREDIT                   1670213 non-null  float64
#  6   AMT_DOWN_PAYMENT             774370 non-null   float64
#  7   AMT_GOODS_PRICE              1284699 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   1670214 non-null  object
#  9   HOUR_APPR_PROCESS_START      1670214 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  1670214 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       1670214 non-null  int64
# ...

# %% [markdown]
# ##### Cleaning of Previous Application Data

# %%
((prev_appl_data.isnull().sum() / prev_appl_data.shape[0]) * 100).sort_values(ascending=False)
# Out:
# RATE_INTEREST_PRIVILEGED       99.643698
# RATE_INTEREST_PRIMARY          99.643698
# AMT_DOWN_PAYMENT               53.636480
# RATE_DOWN_PAYMENT              53.636480
# NAME_TYPE_SUITE                49.119754
# NFLAG_INSURED_ON_APPROVAL      40.298129
# DAYS_TERMINATION               40.298129
# DAYS_LAST_DUE                  40.298129
# DAYS_LAST_DUE_1ST_VERSION      40.298129
# DAYS_FIRST_DUE                 40.298129
# DAYS_FIRST_DRAWING             40.298129
# AMT_GOODS_PRICE                23.081773
# AMT_ANNUITY                    22.286665
# CNT_PAYMENT                    22.286366
# PRODUCT_COMBINATION             0.020716
# AMT_CREDIT                      0.000060
# NAME_YIELD_GROUP                0.000000
# NAME_PORTFOLIO                  0.000000
# NAME_SELLER_INDUSTRY            0.000000
# SELLERPLACE_AREA                0.000000
# CHANNEL_TYPE                    0.000000
# NAME_PRODUCT_TYPE               0.000000
# SK_ID_PREV                      0.000000
# ...

# %%
droplist_colPrevApp = list(prev_appl_data.columns[((prev_appl_data.isnull().sum()/prev_appl_data.index.size)*100) >= 40])

# %%
droplist_colPrevApp
# Out:
# ['AMT_DOWN_PAYMENT',
#  'RATE_DOWN_PAYMENT',
#  'RATE_INTEREST_PRIMARY',
#  'RATE_INTEREST_PRIVILEGED',
#  'NAME_TYPE_SUITE',
#  'DAYS_FIRST_DRAWING',
#  'DAYS_FIRST_DUE',
#  'DAYS_LAST_DUE_1ST_VERSION',
#  'DAYS_LAST_DUE',
#  'DAYS_TERMINATION',
#  'NFLAG_INSURED_ON_APPROVAL']

# %%
prev_appl_data.drop(columns=droplist_colPrevApp,inplace=True)

# %%
((prev_appl_data.isnull().sum() / prev_appl_data.shape[0]) * 100).sort_values(ascending=False)
# Out:
# AMT_GOODS_PRICE                23.081773
# AMT_ANNUITY                    22.286665
# CNT_PAYMENT                    22.286366
# PRODUCT_COMBINATION             0.020716
# AMT_CREDIT                      0.000060
# CODE_REJECT_REASON              0.000000
# NAME_YIELD_GROUP                0.000000
# NAME_SELLER_INDUSTRY            0.000000
# SELLERPLACE_AREA                0.000000
# CHANNEL_TYPE                    0.000000
# NAME_PRODUCT_TYPE               0.000000
# NAME_PORTFOLIO                  0.000000
# NAME_GOODS_CATEGORY             0.000000
# NAME_CLIENT_TYPE                0.000000
# SK_ID_PREV                      0.000000
# NAME_PAYMENT_TYPE               0.000000
# SK_ID_CURR                      0.000000
# NAME_CONTRACT_STATUS            0.000000
# NAME_CASH_LOAN_PURPOSE          0.000000
# NFLAG_LAST_APPL_IN_DAY          0.000000
# FLAG_LAST_APPL_PER_CONTRACT     0.000000
# HOUR_APPR_PROCESS_START         0.000000
# WEEKDAY_APPR_PROCESS_START      0.000000
# ...

# %%
prev_appl_data.shape
# Out:
# (1670214, 26)

# %%
for c in prev_appl_data.select_dtypes('object').columns:
    print(prev_appl_data[c].value_counts(normalize=True)*100)
# Out:
# Cash loans         44.757917
# Consumer loans     43.656142
# Revolving loans    11.565225
# XNA                 0.020716
# Name: NAME_CONTRACT_TYPE, dtype: float64
# TUESDAY      15.274570
# WEDNESDAY    15.268103
# MONDAY       15.181109
# FRIDAY       15.090761
# THURSDAY     14.914197
# SATURDAY     14.407196
# SUNDAY        9.864065
# Name: WEEKDAY_APPR_PROCESS_START, dtype: float64
# Y    99.49258
# N     0.50742
# Name: FLAG_LAST_APPL_PER_CONTRACT, dtype: float64
# XAP                                 55.242083
# XNA                                 40.588691
# Repairs                              1.422872
# Other                                0.934491
# Urgent needs                         0.503648
# Buying a used car                    0.172912
# Building a house or an annex         0.161237
# Everyday expenses                    0.144652
# Medicine                             0.130163
# Payments on other loans              0.115614
# ...

# %%
prev_appl_data.NAME_YIELD_GROUP.value_counts(normalize=True)*100
# Out:
# XNA           30.966990
# middle        23.082791
# high          21.154834
# low_normal    19.284655
# low_action     5.510731
# Name: NAME_YIELD_GROUP, dtype: float64

# %%
# more than 30 % value have XNA data in NAME_YIELD_GROUP column, we can drop this column
prev_appl_data.drop(columns=['NAME_YIELD_GROUP'], inplace=True)

# %%
prev_appl_data.NAME_SELLER_INDUSTRY.value_counts(normalize=True)*100
# Out:
# XNA                     51.234153
# Consumer electronics    23.845148
# Connectivity            16.526565
# Furniture                3.463568
# Construction             1.783065
# Clothing                 1.433888
# Industry                 1.149194
# Auto technology          0.298764
# Jewelry                  0.162195
# MLM partners             0.072745
# Tourism                  0.030715
# Name: NAME_SELLER_INDUSTRY, dtype: float64

# %%
prev_appl_data.drop(columns=['NAME_SELLER_INDUSTRY'], inplace=True)

# %%
prev_appl_data.NAME_PORTFOLIO.value_counts(normalize=True)*100
# Out:
# POS      41.372603
# Cash     27.634962
# XNA      22.286366
# Cards     8.680624
# Cars      0.025446
# Name: NAME_PORTFOLIO, dtype: float64

# %%
prev_appl_data.drop(columns='NAME_PORTFOLIO', inplace=True)

# %%
prev_appl_data.NAME_GOODS_CATEGORY.value_counts(normalize=True)*100
# Out:
# XNA                         56.927376
# Mobile                      13.453845
# Consumer Electronics         7.279067
# Computers                    6.332662
# Audio/Video                  5.953788
# Furniture                    3.212522
# Photo / Cinema Equipment     1.498072
# Construction Materials       1.496515
# Clothing and Accessories     1.410238
# Auto Accessories             0.441919
# Jewelry                      0.376598
# Homewares                    0.300740
# Medical Supplies             0.230090
# Vehicles                     0.201771
# Sport and Leisure            0.178480
# Gardening                    0.159740
# Other                        0.152915
# Office Appliances            0.139683
# Tourism                      0.099329
# Medicine                     0.092802
# Direct Sales                 0.026703
# Fitness                      0.012513
# Additional Service           0.007664
# Education                    0.006406
# Weapon                       0.004610
# ...

# %%
prev_appl_data.drop(columns=['NAME_GOODS_CATEGORY'], inplace=True)

# %%
prev_appl_data.NAME_CLIENT_TYPE.value_counts(normalize=True)*100
# Out:
# Repeater     73.718757
# New          18.043376
# Refreshed     8.121654
# XNA           0.116213
# Name: NAME_CLIENT_TYPE, dtype: float64

# %%
prev_appl_data.NAME_CLIENT_TYPE.mode()[0]
# Out:
# 'Repeater'

# %%
prev_appl_data.NAME_CLIENT_TYPE.replace('XNA',prev_appl_data.NAME_CLIENT_TYPE.mode()[0], inplace=True)

# %%
prev_appl_data.CODE_REJECT_REASON.value_counts(normalize=True)*100
# Out:
# XAP       81.013152
# HC        10.491530
# LIMIT      3.333705
# SCO        2.243245
# CLIENT     1.582791
# SCOFR      0.767027
# XNA        0.313972
# VERIF      0.211650
# SYSTEM     0.042929
# Name: CODE_REJECT_REASON, dtype: float64

# %%
prev_appl_data.drop(columns=['CODE_REJECT_REASON'], inplace=True)

# %%
prev_appl_data.NAME_PAYMENT_TYPE.value_counts(normalize=True)*100
# Out:
# Cash through the bank                        61.881412
# XNA                                          37.563091
# Non-cash from your account                    0.490536
# Cashless from the account of the employer     0.064962
# Name: NAME_PAYMENT_TYPE, dtype: float64

# %%
prev_appl_data.drop(columns=['NAME_PAYMENT_TYPE'], inplace=True)

# %%
prev_appl_data.shape
# Out:
# (1670214, 20)

# %%
prev_appl_data.NAME_CONTRACT_TYPE.value_counts(normalize=True)*100
# Out:
# Cash loans         44.757917
# Consumer loans     43.656142
# Revolving loans    11.565225
# XNA                 0.020716
# Name: NAME_CONTRACT_TYPE, dtype: float64

# %%
prev_appl_data.NAME_CONTRACT_TYPE.mode()[0]
# Out:
# 'Cash loans'

# %%
prev_appl_data.NAME_CONTRACT_TYPE.replace('XNA',prev_appl_data.NAME_CONTRACT_TYPE.mode()[0], inplace=True)

# %%
prev_appl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1670214 non-null  int64
#  1   SK_ID_CURR                   1670214 non-null  int64
#  2   NAME_CONTRACT_TYPE           1670214 non-null  object
#  3   AMT_ANNUITY                  1297979 non-null  float64
#  4   AMT_APPLICATION              1670214 non-null  float64
#  5   AMT_CREDIT                   1670213 non-null  float64
#  6   AMT_GOODS_PRICE              1284699 non-null  float64
#  7   WEEKDAY_APPR_PROCESS_START   1670214 non-null  object
#  8   HOUR_APPR_PROCESS_START      1670214 non-null  int64
#  9   FLAG_LAST_APPL_PER_CONTRACT  1670214 non-null  object
#  10  NFLAG_LAST_APPL_IN_DAY       1670214 non-null  int64
#  11  NAME_CASH_LOAN_PURPOSE       1670214 non-null  object
# ...

# %%
prev_appl_data.PRODUCT_COMBINATION.value_counts()
# Out:
# Cash                              285990
# POS household with interest       263622
# POS mobile with interest          220670
# Cash X-Sell: middle               143883
# Cash X-Sell: low                  130248
# Card Street                       112582
# POS industry with interest         98833
# POS household without interest     82908
# Card X-Sell                        80582
# Cash Street: high                  59639
# Cash X-Sell: high                  59301
# Cash Street: middle                34658
# Cash Street: low                   33834
# POS mobile without interest        24082
# POS other with interest            23879
# POS industry without interest      12602
# POS others without interest         2555
# Name: PRODUCT_COMBINATION, dtype: int64

# %%
##### Knowing the percentage of columns that are approved,refused,cancelled
prev_appl_data.groupby('NAME_CONTRACT_STATUS')['SK_ID_PREV'].count().plot(kind='bar',figsize=(8,4))
plt.show()

# %%
#merging the application_data with previous application data
complete_BankLoan_data = pd.merge(left=BankLoan_data, right=prev_appl_data,how='inner', on='SK_ID_CURR',suffixes='_x')

# %%
complete_BankLoan_data.shape
# Out:
# (1413701, 55)

# %%
##### Knowing the percentage of columns that are approved,refused,cancelled
complete_BankLoan_data.groupby('NAME_CONTRACT_STATUS')['SK_ID_CURR'].count().plot(kind='bar',figsize=(8,4))
plt.show()

# %% [markdown]
# - Across complete loan data, Approved loans outnumbered Canceled, Refused and Unused offer.

# %%
#### Dividing the data based on the Contract Status:
complete_BankLoan_data_Approved = complete_BankLoan_data[complete_BankLoan_data['NAME_CONTRACT_STATUS'] == 'Approved']
complete_BankLoan_data_Canceled = complete_BankLoan_data[complete_BankLoan_data['NAME_CONTRACT_STATUS'] == 'Canceled']
complete_BankLoan_data_Refused = complete_BankLoan_data[complete_BankLoan_data['NAME_CONTRACT_STATUS'] == 'Refused']
complete_BankLoan_data_Unused = complete_BankLoan_data[complete_BankLoan_data['NAME_CONTRACT_STATUS'] == 'Unused offer']

# %%
def plot_func1(dataframe,dim):
    fig = plt.figure(figsize=(13,10))
    ax1 = plt.subplot(221)
    dataframe[dim].value_counts().plot.pie(autopct = "%1.0f%%" , ax = ax1)
    plt.title("Plotting data for the dimension " + dim)
    ax2 = plt.subplot(222)
    sns.countplot(x=dim,hue='NAME_CONTRACT_STATUS',data=dataframe,ax=ax2)
    plt.xticks(rotation=90)
    plt.title("Plotting data for target in terms of total count")
    ax3 = plt.subplot(223)
    dfStatus=pd.DataFrame()
    dfStatus['Approved'] = ((complete_BankLoan_data_Approved[dim].value_counts())/len(complete_BankLoan_data_Approved))
    dfStatus['Canceled'] = ((complete_BankLoan_data_Canceled[dim].value_counts())/len(complete_BankLoan_data_Canceled))
    dfStatus['Refused'] = ((complete_BankLoan_data_Refused[dim].value_counts())/len(complete_BankLoan_data_Refused))
    dfStatus['Unused'] = ((complete_BankLoan_data_Unused[dim].value_counts())/len(complete_BankLoan_data_Unused))
    dfStatus.plot.bar(ax=ax3)
    plt.title("plotting data in terms of percentage")
    fig.tight_layout()
    plt.show()

# %%
plot_func1(complete_BankLoan_data,'CODE_GENDER')

# %% [markdown]
# - From the above graphs we can infer that females seems to have more number of application and also the Approval percentage is high for them. Even, the percentage for Canceled, refused and Unused status are on higher side for female as comapred to male.

# %%
plot_func1(complete_BankLoan_data,'NAME_EDUCATION_TYPE')

# %% [markdown]
# - Secondary/secondary special education type has more percentage for approval, canceled and refused.
# - For, higher education, Unused offer have higher percentage as compared to the other contract status.

# %%
plot_func1(complete_BankLoan_data,'CHANNEL_TYPE')

# %% [markdown]
# - Approved loan percentage is more in Country-wide channel type.
# - Unused loan and Canceled loan percentage is highest among Country-wide and Credit and cash offices respectively.

# %%
plot_func1(complete_BankLoan_data,'NAME_CLIENT_TYPE')

# %% [markdown]
# - Repeater client type seems to have more percentage of Canceled and Refused loan.

# %%
def plot3_func(var):
    fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(15,5))
    
    s1=sns.countplot(ax=ax1,x=complete_BankLoan_data_Approved[var], data=complete_BankLoan_data_Approved)
    s1.set_xticklabels(s1.get_xticklabels(),rotation=90)
    ax1.set_title("Approved", fontsize=10) 
    ax1.set_xlabel(var)
    ax1.set_ylabel("Count of Loans")    
    
    s2=sns.countplot(ax=ax2,x=complete_BankLoan_data_Canceled[var], data=complete_BankLoan_data_Canceled)
    s2.set_xticklabels(s2.get_xticklabels(),rotation=90)
    ax2.set_title("Canceled", fontsize=10)
    ax2.set_xlabel(var)
    ax2.set_ylabel("Count of Loans")    
    
    s3=sns.countplot(ax=ax3,x=complete_BankLoan_data_Refused[var], data=complete_BankLoan_data_Refused)
    s3.set_xticklabels(s3.get_xticklabels(),rotation=90)
    ax3.set_title("Refused", fontsize=10)
    ax3.set_xlabel(var)
    ax3.set_ylabel("Count of Loans")    
    plt.show()

# %%
plot3_func('PRODUCT_COMBINATION')

# %% [markdown]
# - POS household with interest product combination has more number of Approved loans. Whereas Cash product conbination has more no of Canceled loans. And, Cash X-Sell:low sees more no of Refused loans.

# %%
plot3_func('CHANNEL_TYPE')

# %% [markdown]
# - Country-wide channel type sees more no of Approved loans.
# - Whereas, Credit and cash offices channel type sees more number of Canceled and Refused loans.

# %%
plot3_func('NAME_PRODUCT_TYPE')

# %% [markdown]
# - X-sell product type have more no of Approved loans.

# %%
plot3_func('NAME_CLIENT_TYPE')

# %% [markdown]
# - Repeater client type seems to have more number of loans across each Contract status

# %% [markdown]
# #### Correlation heatmap for Approved

# %%
corr_a = complete_BankLoan_data_Approved.corr()
mask_a = np.zeros_like(corr_a)
mask_a[np.triu_indices_from(mask_a)]= True
f, ax = plt.subplots(figsize=(11, 9))
with sns.axes_style('white'):
    ax= sns.heatmap(corr_a, mask=mask_a, vmax=.3, square=True)
    plt.title('Correlation Heat map for Approved',fontdict={'fontsize':20})
    plt.show()

# %%
approved_corr = complete_BankLoan_data_Approved.corr().abs().unstack().dropna()
approved_corr = approved_corr[~(approved_corr==1.0)]
round(approved_corr.sort_values(kind='quicksort').drop_duplicates().tail(10).sort_values(ascending=False)*100,2)
# Out:
# DAYS_BIRTH              Age                            99.97
# AMT_CREDITx             AMT_GOODS_PRICEx               99.33
# AMT_GOODS_PRICE_        AMT_CREDIT_                    98.65
# AMT_CREDITx             AMT_APPLICATION                96.18
# REGION_RATING_CLIENT    REGION_RATING_CLIENT_W_CITY    94.26
# CNT_FAM_MEMBERS         CNT_CHILDREN                   88.29
# REG_CITY_NOT_WORK_CITY  LIVE_CITY_NOT_WORK_CITY        83.48
# AMT_GOODS_PRICEx        AMT_ANNUITYx                   83.13
# AMT_CREDITx             AMT_ANNUITYx                   82.65
# AMT_ANNUITYx            AMT_APPLICATION                81.45
# dtype: float64

# %% [markdown]
# #### Correlation heatmap for Canceled

# %%
corr_c = complete_BankLoan_data_Canceled.corr()
mask_c = np.zeros_like(corr_c)
mask_c[np.triu_indices_from(mask_c)]= True
f, ax = plt.subplots(figsize=(11, 9))
with sns.axes_style('white'):
    ax= sns.heatmap(corr_c, mask=mask_c, vmax=.3, square=True)
    plt.show()

# %%
canceled_corr = complete_BankLoan_data_Canceled.corr().abs().unstack().dropna()
canceled_corr = canceled_corr[~(canceled_corr==1.0)]
canceled_corr.sort_values(kind='quicksort').drop_duplicates().tail(10).sort_values(ascending=False)*100
# Out:
# Age                          DAYS_BIRTH                 99.970706
# AMT_CREDITx                  AMT_APPLICATION            99.682219
# AMT_GOODS_PRICEx             AMT_CREDITx                99.164441
# AMT_GOODS_PRICE_             AMT_CREDIT_                98.580722
# REGION_RATING_CLIENT_W_CITY  REGION_RATING_CLIENT       95.313889
# CNT_CHILDREN                 CNT_FAM_MEMBERS            86.883077
# REG_CITY_NOT_WORK_CITY       LIVE_CITY_NOT_WORK_CITY    83.161710
# AMT_APPLICATION              AMT_ANNUITYx               79.177422
# AMT_ANNUITYx                 AMT_GOODS_PRICEx           79.157792
#                              AMT_CREDITx                78.672586
# dtype: float64

# %% [markdown]
# #### Correlation heatmap for Refused

# %%
corr_r = complete_BankLoan_data_Refused.corr()
mask_r = np.zeros_like(corr_r)
mask_r[np.triu_indices_from(mask_r)]= True
f, ax = plt.subplots(figsize=(11, 9))
with sns.axes_style('white'):
    ax= sns.heatmap(corr_r, mask=mask_r, vmax=.3, square=True)
    plt.show()

# %%
refused_corr = complete_BankLoan_data_Refused.corr().abs().unstack().dropna()
refused_corr = refused_corr[~(refused_corr==1.0)]
refused_corr.sort_values(kind='quicksort').drop_duplicates().tail(10).sort_values(ascending=False)*100
# Out:
# DAYS_BIRTH                   Age                       99.971128
# AMT_GOODS_PRICEx             AMT_APPLICATION           99.966561
#                              AMT_CREDITx               99.184204
# AMT_CREDIT_                  AMT_GOODS_PRICE_          98.482102
# AMT_CREDITx                  AMT_APPLICATION           98.368351
# REGION_RATING_CLIENT_W_CITY  REGION_RATING_CLIENT      94.727166
# CNT_FAM_MEMBERS              CNT_CHILDREN              87.416672
# AMT_GOODS_PRICEx             AMT_ANNUITYx              82.529634
# AMT_ANNUITYx                 AMT_CREDITx               82.305435
# LIVE_CITY_NOT_WORK_CITY      REG_CITY_NOT_WORK_CITY    82.111967
# dtype: float64

# %% [markdown]
# #### Correlation heatmap for Unused

# %%
corr_u = complete_BankLoan_data_Unused.corr()
mask_u = np.zeros_like(corr_u)
mask_u[np.triu_indices_from(mask_u)]= True
f, ax = plt.subplots(figsize=(11, 9))
with sns.axes_style('white'):
    ax= sns.heatmap(corr_u, mask=mask_u, vmax=.3, square=True)
    plt.show()

# %%
unused_corr = complete_BankLoan_data_Unused.corr().abs().unstack().dropna()
unused_corr = unused_corr[~(unused_corr==1.0)]
round(unused_corr.sort_values(kind='quicksort').drop_duplicates().tail(10).sort_values(ascending=False)*100,3)
# Out:
# AMT_CREDITx             AMT_GOODS_PRICEx               99.997
#                         AMT_APPLICATION                99.976
# Age                     DAYS_BIRTH                     99.964
# AMT_CREDIT_             AMT_GOODS_PRICE_               98.592
# REGION_RATING_CLIENT    REGION_RATING_CLIENT_W_CITY    95.837
# AMT_CREDITx             AMT_ANNUITYx                   94.031
# AMT_ANNUITYx            AMT_GOODS_PRICEx               93.990
#                         AMT_APPLICATION                93.723
# CNT_CHILDREN            CNT_FAM_MEMBERS                89.096
# REG_CITY_NOT_WORK_CITY  LIVE_CITY_NOT_WORK_CITY        81.347
# dtype: float64

# %% [markdown]
# # Conclusion

# %% [markdown]
# *** Banks should focus on the client from age group of 41 to 70 as they have more probability of being financial stable and shows less paying  difficulties**
#
# *** 20-30 age group face much difficulty in repaying,so can be avoided**
#
# *** Banks should focus more on education type 'Higher education' and avoid Secondary/secondary special,  incomplete higher or lower secondary as they have more difficulty in repaying.**
#
# *** Avoid income type 'Working' clients as they have high  percentage of paying difficulties. Instead focus on Commercial associates, pensioner and State servant**
#
# *** Revolving loans have a better chance to be returned**
#
# *** Provide more loans to females,as they have less difficulty in returning the loan than men.**
#
# *** Give preference to widowed & married people**
#
# *** Car, property owners find it less difficult to repay the loan,they must be preferred**
#
# *** Focus on clients from housing type ‘House/apartment’ as they are having less paying difficulties.**
#
# *** Bank should focus 'Country-wide' channel type sees  more no of Approved loans. Whereas, Credit and cash  offices channel type sees more number of Canceled and  Refused loans**
